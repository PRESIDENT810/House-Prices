# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("processed_data.csv",'r')

# %%
data.head()
# Out:
#                                  ,Id,MSSubClass,LotF  ontage,LotA  ea,Ove  \
# 0  0,1,60,65.0,8450,7,5,2003,2003,196.0,706,0,150...          NaN     NaN
# 1  1,2,20,80.0,9600,6,8,1976,1976,0.0,978,0,284,1...          NaN     NaN
# 2  2,3,60,68.0,11250,7,5,2001,2002,162.0,486,0,43...          NaN     NaN
# 3  3,4,70,60.0,9550,7,5,1915,1970,0.0,216,0,540,7...          NaN     NaN
# 4  4,5,60,84.0,14260,8,5,2000,2000,350.0,655,0,49...          NaN     NaN
#
#    allQual,Ove  allCond,Yea  Built,Yea  RemodAdd,MasVn   A  \
# 0          NaN          NaN        NaN             NaN NaN
# 1          NaN          NaN        NaN             NaN NaN
# 2          NaN          NaN        NaN             NaN NaN
# 3          NaN          NaN        NaN             NaN NaN
# 4          NaN          NaN        NaN             NaN NaN
#
#    ea,BsmtFinSF1,BsmtFinSF2,BsmtUnfSF,TotalBsmtSF,1stFl  SF,2ndFl  ...  \
# 0                                                NaN          NaN  ...
# ...

# %%
data.iloc[0][0:3]
# Out:
# ,Id,MSSubClass,LotF    0,1,60,65.0,8450,7,5,2003,2003,196.0,706,0,150...
# ontage,LotA                                                          NaN
# ea,Ove                                                               NaN
# Name: 0, dtype: object
