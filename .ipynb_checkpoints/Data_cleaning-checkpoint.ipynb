# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
'''
Missing: 
    LotFrontage(1201/1460), float64
    Alley(91/1460), string
    MasVnrType(1452/1460), string
    MasVnrArea(1452/1460), float64
    BsmtQual(1423/1460), string
    BsmtCond(1423/1460), string
    BsmtExposure(1422/1460), string
    BsmtFinType1(1423/1460), string
    BsmtFinType2(1422/1420),s string
    Electrical(1459/1460), string
    FireplaceQu(770/1460), string
    GarageType(1379/1460), string
    GarageYrBit(1379/1460), float64
    GarageFinish(1379/1460), string
    GarageQual(1379/1460), string
    GarageCond(1379/1460), string
    PoolQC(7/1460), string
    Fence(281/1460), string
    MiscFeature(54), string
'''
'''
Only a few missing for MasVnrType, MasVnrArea, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, Electrical, 
we fill these NAs by Gaussian distribution estimation
'''
# Out:
# '\nOnly a few missing for MasVnrType, MasVnrArea, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, Electrical, \nwe fill these NAs by Gaussian distribution estimation\n'

# %%
processed_data = pd.get_dummies(data)

# %%
processed_data.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  SaleType_New  \
# 0          2003       196.0         706  ...               0             0
# 1          1976         0.0         978  ...               0             0
# 2          2002       162.0         486  ...               0             0
# 3          1970         0.0         216  ...               0             0
# 4          2000       350.0         655  ...               0             0
#
# ...

# %%
processed_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
processed_data.to_csv("processed_data.csv")

# %%
import xgboost
from sklearn.model_selection import GridSearchCV

# %%
data_y = processed_data["SalePrice"]
data_X = processed_data.drop(["SalePrice","Id"],axis=1)

# %%
XGBR = xgboost.XGBRFRegressor()
XGBR_grid = {
    "min_chile_weight": [0.5,1,2,5],
    "max_depth": [2,3,5],
    "gamma": [0,0.1,0.2,0.5],
    "max_delta_step": [0,1],
    "reg_lambda": [1,2,5,10,20,50],
    "n_estimators": [100]
}
gsXGBR = GridSearchCV(XGBR,param_grid=XGBR_grid,n_jobs=-1,cv=5)
gsXGBR.fit(data_X,data_y)
XGBR_best = gsXGBR.best_score_
XGBR = gsXGBC.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-8bb15da21a0c> in <module>
#       9 }
#      10 gsXGBR = GridSearchCV(XGBR,param_grid=XGBR_grid,n_jobs=-1,cv=5)
# ---> 11 gsXGBR.fit(data_X,data_y)
#      12 XGBR_best = gsXGBR.best_score_
#      13 XGBR = gsXGBC.best_estimator_
#
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# ...

# %%
submit_data = pd.read_csv("test.csv")

# %%
submit_X = pd.get_dummies(submit_data)
submit_X = submit_X.drop(["Id"],axis=1)

# %%
def fill_col(column):
    col_name = column.name
    global cnt
    global submit_X
    if not (col_name in submit_X.columns):
        submit_X[col_name] = 0
        print(col_name)
    
data_X.apply(fill_col,axis=0)

# %%
submit_X = submit_X[data_X.columns]

# %%
predict_y = XGBR.predict(submit_X)

# %%
result = pd.DataFrame({"Id":submit_data["Id"],"SalePrice":predict_y})

# %%
result.head()

# %%
result.to_csv("result.csv",index=False)
